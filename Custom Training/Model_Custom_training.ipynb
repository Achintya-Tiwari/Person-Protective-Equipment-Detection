# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source="/content/drive/MyDrive/DIP_SBMP/1886-48241.webp"

# %% [markdown]
# ## **Custom Data Training **

# %%
# !yolo task=detect mode=train model=yolov8l.pt data="//content//drive//MyDrive//DIP_SBMP//data.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
